# %% [markdown]
# ## Pandas Tutorial
#
# Are you starting with Data Science? Pandas is perhaps the first best thing you will need. And it's really easy!
#
# After reading (and practising) this tutorial you will learn how to:
#
# - Create, add, remove and rename columns
# - Read, select and filter data
# - Retrieve statistics for data
# - Sort and group data
# - Manipulate data
#
# Happy learning!

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('max_colwidth', 100)

# %% [markdown]
# ### 1. Rows and Columns (create, add, remove, rename)

# %% [markdown]
# #### Create a DataFrame + add rows and columns

# %%
countries = pd.DataFrame({
    'Name':['Greece', 'Paraguay', 'Ireland'],
    'Population':[10.77, 6.62, 4.78],
    'Area':[128.9, 397.3, 68.89]
})
#Note: if you don't specify 'columns', then they will be placed in alphabetical order

countries.head()
# Out:
#        Name  Population    Area
# 0    Greece       10.77  128.90
# 1  Paraguay        6.62  397.30
# 2   Ireland        4.78   68.89

# %% [markdown]
# #### Add data (a row) with *append*

# %%
countries = countries.append({'Name':'Japan',
                              'Population':127.25,
                              'Area':364.5}, ignore_index=True)
#Note: If you type the name of a column that does not exist, then it will be created with NaNs for all other rows
countries.head()
# Out:
#        Name  Population    Area
# 0    Greece       10.77  128.90
# 1  Paraguay        6.62  397.30
# 2   Ireland        4.78   68.89
# 3     Japan      127.25  364.50

# %%
names = ['Singapore', 'Gabon']
populations = [4.46, 1.64]
areas = [0.687, 257.67]
for i in range(len(names)):
    countries = countries.append({'Name':names[i],
                              'Population':populations[i],
                              'Area':areas[i]}, ignore_index=True)
countries.head(10)
# Out:
#         Name  Population     Area
# 0     Greece       10.77  128.900
# 1   Paraguay        6.62  397.300
# 2    Ireland        4.78   68.890
# 3      Japan      127.25  364.500
# 4  Singapore        4.46    0.687
# 5      Gabon        1.64  257.670

# %% [markdown]
# #### Add feature (a column) with *assign*. Handcrafted data

# %%
countries = countries.assign(GDP = [22.08,3.81,45.83,46.72,51.7,11.43])

# %% [markdown]
# #### Add a feature (a column) from interactions with other features

# %%
countries['PopulationPerArea'] = countries['Population']/countries['Area']
countries.head(10)
# Out:
#         Name  Population     Area    GDP  PopulationPerArea
# 0     Greece       10.77  128.900  22.08           0.083553
# 1   Paraguay        6.62  397.300   3.81           0.016662
# 2    Ireland        4.78   68.890  45.83           0.069386
# 3      Japan      127.25  364.500  46.72           0.349108
# 4  Singapore        4.46    0.687  51.70           6.491994
# 5      Gabon        1.64  257.670  11.43           0.006365

# %% [markdown]
# #### Remove (drop) a row

# %%
countries = countries.drop(3, axis=0) #Drop by index
countries.head(10)
# Out:
#         Name  Population     Area    GDP  PopulationPerArea
# 0     Greece       10.77  128.900  22.08           0.083553
# 1   Paraguay        6.62  397.300   3.81           0.016662
# 2    Ireland        4.78   68.890  45.83           0.069386
# 4  Singapore        4.46    0.687  51.70           6.491994
# 5      Gabon        1.64  257.670  11.43           0.006365

# %% [markdown]
# #### Remove (drop) a column

# %%
countries = countries.drop(['PopulationPerArea'], axis=1)
countries.head(10)
# Out:
#         Name  Population     Area    GDP
# 0     Greece       10.77  128.900  22.08
# 1   Paraguay        6.62  397.300   3.81
# 2    Ireland        4.78   68.890  45.83
# 4  Singapore        4.46    0.687  51.70
# 5      Gabon        1.64  257.670  11.43

# %% [markdown]
# #### Rename a column

# %%
countries = countries.rename(columns={'GDP':'Money'})
countries.head(10)
# Out:
#         Name  Population     Area  Money
# 0     Greece       10.77  128.900  22.08
# 1   Paraguay        6.62  397.300   3.81
# 2    Ireland        4.78   68.890  45.83
# 4  Singapore        4.46    0.687  51.70
# 5      Gabon        1.64  257.670  11.43

# %% [markdown]
# #### Rename all columns

# %%
c = countries.copy()
c.columns = ['1','2','3','4']
c
# Out:
#            1      2        3      4
# 0     Greece  10.77  128.900  22.08
# 1   Paraguay   6.62  397.300   3.81
# 2    Ireland   4.78   68.890  45.83
# 4  Singapore   4.46    0.687  51.70
# 5      Gabon   1.64  257.670  11.43

# %% [markdown]
# ### 2. Selecting Data

# %% [markdown]
# #### Subsets of columns of DataFrame

# %%
print(type(countries['Name'])) # A single column in [] is called Series
countries['Name']
# Out:
# <class 'pandas.core.series.Series'>
# 0       Greece
# 1     Paraguay
# 2      Ireland
# 4    Singapore
# 5        Gabon
# Name: Name, dtype: object

# %%
type(countries[['Name']]) # With [[]] it is again a DataFrame
countries[['Name']]
# Out:
#         Name
# 0     Greece
# 1   Paraguay
# 2    Ireland
# 4  Singapore
# 5      Gabon

# %%
countries[['Name','Money']] # More columns
# Out:
#         Name  Money
# 0     Greece  22.08
# 1   Paraguay   3.81
# 2    Ireland  45.83
# 4  Singapore  51.70
# 5      Gabon  11.43

# %% [markdown]
# #### Subsets of rows of DataFrame with *slice*

# %%
countries[0:2] # Return the rows from the 0th to the 1st position
# Out:
#        Name  Population   Area  Money
# 0    Greece       10.77  128.9  22.08
# 1  Paraguay        6.62  397.3   3.81

# %% [markdown]
# #### Subsets of rows of DataFrame with *iloc*
# Same as slice

# %%
countries.iloc[0:2]
# Out:
#        Name  Population   Area  Money
# 0    Greece       10.77  128.9  22.08
# 1  Paraguay        6.62  397.3   3.81

# %% [markdown]
# #### Subsets of rows and columns of DataFrame with iloc

# %%
countries.iloc[0:4,0:2]
# Out:
#         Name  Population
# 0     Greece       10.77
# 1   Paraguay        6.62
# 2    Ireland        4.78
# 4  Singapore        4.46

# %% [markdown]
# #### Select rows of DataFrame with *loc*
# loc gets rows (or columns) with particular labels from the index

# %%
countries.loc[[1,2]]
# Out:
#        Name  Population    Area  Money
# 1  Paraguay        6.62  397.30   3.81
# 2   Ireland        4.78   68.89  45.83

# %% [markdown]
# #### Select rows and columns of DataFrame with loc

# %%
countries.loc[[1,2], ['Name','Area']]
# Out:
#        Name    Area
# 1  Paraguay  397.30
# 2   Ireland   68.89

# %% [markdown]
# #### Select specific cell (row,column) of a DataFrame with *at*

# %%
countries.at[1,'Name'] # index,column_name
# Out:
# 'Paraguay'

# %% [markdown]
# ### 3. Filtering Data

# %% [markdown]
# #### Relational Operators

# %%
countries[countries['Area']>100]
# Out:
#        Name  Population    Area  Money
# 0    Greece       10.77  128.90  22.08
# 1  Paraguay        6.62  397.30   3.81
# 5     Gabon        1.64  257.67  11.43

# %%
countries.loc[countries['Area']>100] # better
# Out:
#        Name  Population    Area  Money
# 0    Greece       10.77  128.90  22.08
# 1  Paraguay        6.62  397.30   3.81
# 5     Gabon        1.64  257.67  11.43

# %%
countries.query('Area>100') # faster for big dataframes
# Out:
#        Name  Population    Area  Money
# 0    Greece       10.77  128.90  22.08
# 1  Paraguay        6.62  397.30   3.81
# 5     Gabon        1.64  257.67  11.43

# %% [markdown]
# #### Logical Operators

# %%
countries[(countries['Area']>100) & (countries['Population']>5)] # don't forget brackets
# Out:
#        Name  Population   Area  Money
# 0    Greece       10.77  128.9  22.08
# 1  Paraguay        6.62  397.3   3.81

# %%
countries[countries['Name'].isin(['Greece','Gabon'])]
# Out:
#      Name  Population    Area  Money
# 0  Greece       10.77  128.90  22.08
# 5   Gabon        1.64  257.67  11.43

# %% [markdown]
# #### If contains string

# %%
countries[countries['Name'].str.contains('e')]
# Out:
#         Name  Population     Area  Money
# 0     Greece       10.77  128.900  22.08
# 2    Ireland        4.78   68.890  45.83
# 4  Singapore        4.46    0.687  51.70

# %% [markdown]
# ### 4. Reading Data
# House Prices Dataset from https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %%
train = pd.read_csv('Encoding_Categorical_Features_train.csv', sep=',')
test = pd.read_csv('Encoding_Categorical_Features_test.csv', sep=',')

# %% [markdown]
# #### Headers of DataFrame

# %%
train.columns.values
# Out:
# array(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
#        'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature',
#        'MiscVal', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition',
#        'SalePrice'], dtype=object)

# %% [markdown]
# #### Dimensions of DataFrame

# %%
train.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### 5. Statistics

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#         BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean     46.549315   567.240411  1057.429452  1162.626712   346.992466
# std     161.319273   441.866955   438.705324   386.587738   436.528436
# min       0.000000     0.000000     0.000000   334.000000     0.000000
# 25%       0.000000   223.000000   795.750000   882.000000     0.000000
# 50%       0.000000   477.500000   991.500000  1087.000000     0.000000
# 75%       0.000000   808.000000  1298.250000  1391.250000   728.000000
# max    1474.000000  2336.000000  6110.000000  4692.000000  2065.000000
#
#        LowQualFinSF    GrLivArea  BsmtFullBath  BsmtHalfBath     FullBath  \
# count   1460.000000  1460.000000   1460.000000   1460.000000  1460.000000
# mean       5.844521  1515.463699      0.425342      0.057534     1.565068
# std       48.623081   525.480383      0.518911      0.238753     0.550916
# min        0.000000   334.000000      0.000000      0.000000     0.000000
# 25%        0.000000  1129.500000      0.000000      0.000000     1.000000
# 50%        0.000000  1464.000000      0.000000      0.000000     2.000000
# 75%        0.000000  1776.750000      1.000000      0.000000     2.000000
# max      572.000000  5642.000000      3.000000      2.000000     3.000000
#
#           HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd   Fireplaces  \
# count  1460.000000   1460.000000   1460.000000   1460.000000  1460.000000
# mean      0.382877      2.866438      1.046575      6.517808     0.613014
# std       0.502885      0.815778      0.220338      1.625393     0.644666
# min       0.000000      0.000000      0.000000      2.000000     0.000000
# 25%       0.000000      2.000000      1.000000      5.000000     0.000000
# 50%       0.000000      3.000000      1.000000      6.000000     1.000000
# 75%       1.000000      3.000000      1.000000      7.000000     1.000000
# max       2.000000      8.000000      3.000000     14.000000     3.000000
#
#        GarageYrBlt   GarageCars   GarageArea   WoodDeckSF  OpenPorchSF  \
# count  1379.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1978.506164     1.767123   472.980137    94.244521    46.660274
# std      24.689725     0.747315   213.804841   125.338794    66.256028
# min    1900.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1961.000000     1.000000   334.500000     0.000000     0.000000
# 50%    1980.000000     2.000000   480.000000     0.000000    25.000000
# 75%    2002.000000     2.000000   576.000000   168.000000    68.000000
# max    2010.000000     4.000000  1418.000000   857.000000   547.000000
#
#        EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea       MiscVal  \
# count    1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean       21.954110     3.409589    15.060959     2.758904     43.489041
# std        61.119149    29.317331    55.757415    40.177307    496.123024
# min         0.000000     0.000000     0.000000     0.000000      0.000000
# 25%         0.000000     0.000000     0.000000     0.000000      0.000000
# 50%         0.000000     0.000000     0.000000     0.000000      0.000000
# 75%         0.000000     0.000000     0.000000     0.000000      0.000000
# max       552.000000   508.000000   480.000000   738.000000  15500.000000
#
#             MoSold       YrSold      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean      6.321918  2007.815753  180921.195890
# std       2.703626     1.328095   79442.502883
# min       1.000000  2006.000000   34900.000000
# 25%       5.000000  2007.000000  129975.000000
# 50%       6.000000  2008.000000  163000.000000
# 75%       8.000000  2009.000000  214000.000000
# max      12.000000  2010.000000  755000.000000

# %% [markdown]
# #### mean, median, quantile, min, max

# %%
print('Year Build mean: {:.2f}'.format(train['YearBuilt'].mean()))
print('Year Build median: {:.2f}'.format(train['YearBuilt'].median()))
print('Year Build quantile 25%: {:.2f}'.format(train['YearBuilt'].quantile(0.25)))
print('Year Build quantile 70%: {:.2f}'.format(train['YearBuilt'].quantile(0.7)))
print('Year Build min: {:.2f}'.format(train['YearBuilt'].min()))
print('Year Build max: {:.2f}'.format(train['YearBuilt'].max()))
# Out:
# Year Build mean: 1971.27
# Year Build median: 1973.00
# Year Build quantile 25%: 1954.00
# Year Build quantile 70%: 1997.30
# Year Build min: 1872.00
# Year Build max: 2010.00

# %% [markdown]
# #### Find the value of the index that has max

# %%
train['YearBuilt'].idxmax()
# Out:
# 378

# %% [markdown]
# #### Count the different occurencies of a column

# %%
train['Fireplaces'].value_counts()
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %% [markdown]
# #### Find unique instances of a column

# %%
print(train['Fireplaces'].nunique()) #how many unique
train['Fireplaces'].unique() #displays the unique
# Out:
# 4
# array([0, 1, 2, 3], dtype=int64)

# %% [markdown]
# #### Count

# %%
train['YearBuilt'].count()
# Out:
# 1460

# %% [markdown]
# #### Sum

# %%
train['SalePrice'].sum()
# Out:
# 264144946

# %% [markdown]
# #### Mode (Most common value)

# %%
train['YearBuilt'].mode()
# Out:
# 0    2006
# dtype: int64

# %% [markdown]
# ### 6. Sorting and Grouping Data

# %% [markdown]
# #### Sort

# %%
train.sort_values(by='SalePrice', ascending=False).head()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 691          Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1182         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
# 1169         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 898          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 803          Lvl    AllPub    Inside       Gtl      NridgHt       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 691        Norm     1Fam     2Story           10            6       1994
# 1182       Norm     1Fam     2Story           10            5       1996
# 1169       Norm     1Fam     2Story           10            5       1995
# 898        Norm     1Fam     1Story            9            5       2009
# 803        Norm     1Fam     2Story            9            5       2008
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 691           1995     Gable  WdShngl     HdBoard     HdBoard    BrkFace
# 1182          1996       Hip  CompShg     Wd Sdng     ImStucc       None
# 1169          1996       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 898           2010       Hip  CompShg     VinylSd     VinylSd      Stone
# 803           2009       Hip  CompShg     VinylSd     VinylSd      Stone
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 691       1170.0        Ex        TA      PConc       Ex       TA
# 1182         0.0        Gd        TA      PConc       Ex       TA
# 1169      1378.0        Gd        Gd      PConc       Ex       TA
# 898        760.0        Ex        TA      PConc       Ex       TA
# 803        424.0        Ex        TA      PConc       Ex       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 691            Gd          GLQ        1455          Unf           0
# 1182           Av          GLQ        2096          Unf           0
# 1169           Gd          GLQ        1387          Unf           0
# 898            Gd          GLQ        2188          Unf           0
# 803            Gd          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 691         989         2444    GasA        Ex          Y      SBrkr
# 1182        300         2396    GasA        Ex          Y      SBrkr
# 1169        543         1930    GasA        Ex          Y      SBrkr
# 898         142         2330    GasA        Ex          Y      SBrkr
# 803        1734         1734    GasA        Ex          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 691       2444      1872             0       4316             0             1
# 1182      2411      2065             0       4476             1             0
# 1169      1831      1796             0       3627             1             0
# 898       2364         0             0       2364             1             0
# 803       1734      1088             0       2822             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 691          3         1             4             1          Ex
# 1182         3         1             4             1          Ex
# 1169         3         1             4             1          Gd
# 898          2         1             2             1          Ex
# 803          3         1             4             1          Ex
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 691             10        Typ           2          Ex     Attchd       1994.0
# 1182            10        Typ           2          TA     Attchd       1996.0
# 1169            10        Typ           1          TA     Attchd       1995.0
# 898             11        Typ           2          Gd     Attchd       2009.0
# 803             12        Typ           1          Gd    BuiltIn       2009.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 691           Fin           3         832         TA         TA          Y
# 1182          Fin           3         813         TA         TA          Y
# 1169          Fin           3         807         TA         TA          Y
# 898           Fin           3         820         TA         TA          Y
# 803           RFn           3        1020         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 691          382           50              0          0            0
# 1182         171           78              0          0            0
# 1169         361           76              0          0            0
# 898            0           67              0          0            0
# 803           52          170              0          0          192
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 691          0    NaN    NaN         NaN        0       1    2007       WD
# 1182       555     Ex  MnPrv         NaN        0       7    2007       WD
# 1169         0    NaN    NaN         NaN        0       7    2006       WD
# 898          0    NaN    NaN         NaN        0       3    2010      New
# 803          0    NaN    NaN         NaN        0       1    2009      New
#
#      SaleCondition  SalePrice
# 691         Normal     755000
# 1182       Abnorml     745000
# 1169        Normal     625000
# 898        Partial     611657
# 803        Partial     582933

# %%
train.sort_values(['Fireplaces', 'SalePrice'], ascending=[0,1])[['Fireplaces', 'SalePrice']].head(8) # 0 means ascending=False
# Out:
#       Fireplaces  SalePrice
# 1298           3     160000
# 166            3     190000
# 605            3     205000
# 642            3     345000
# 309            3     360000
# 393            2     100000
# 662            2     110000
# 9              2     118000

# %% [markdown]
# #### Group

# %%
train.groupby('Fireplaces')['SalePrice'].mean()
# Out:
# Fireplaces
# 0    141331.482609
# 1    211843.909231
# 2    240588.539130
# 3    252000.000000
# Name: SalePrice, dtype: float64

# %%
for fireplace, df in train.groupby('Fireplaces')['SalePrice']:
    print(fireplace,"\n",df)
# Out:
# 0
#  0       208500
# 5       143000
# 10      129500
# 12      144000
# 15      132000
# 17       90000
# 18      159000
# 19      139000
# 26      134800
# 29       68500
# 30       40000
# 31      149350
# 32      179900
# 36      145000
# 38      109000
# 39       82000
# 42      144000
# 43      130250
# 44      141000
# 47      249700
# 48      113000
# 49      127000
# 50      177000
# 52      110000
# 56      172500
# 57      196500
# 59      124900
# 60      158000
# 61      101000
# 63      140000
# 64      219500
# 67      226000
# 68       80000
# 71      129500
# 73      144900
# 74      107400
# 75       91000
# 76      135750
# 77      127000
# 78      136500
# 79      110000
# 81      153500
# 83      126500
# 87      164500
# 88       85000
# 89      123600
# 90      109900
# 91       98600
# 92      163500
# 94      204750
# 96      214000
# 97       94750
# 98       83000
# 99      128950
# 102     118964
# 103     198900
# 106     100000
# 107     115000
# 108     115000
# 110     136900
# 117     155000
# 121     100000
# 122     136000
# 123     153900
# 125      84500
# 129     150000
# 132     150750
# 133     220000
# 137     171000
# 139     231500
# 141     260000
# 142     166000
# 143     204000
# 144     125000
# 145     130000
# 146     105000
# 148     141000
# 149     115000
# 150     122000
# 154     125000
# 155      79000
# 156     109500
# 160     162500
# 163     103200
# 164     152000
# 165     127500
# 170     128500
# 179     100000
# 183     200000
# 184     127000
# 186     173000
# 187     135000
# 191     184000
# 192     192000
# 193     130000
# 194     127000
# 198     104000
# 200     140000
# 202     112000
# 204     110000
# 205     180500
# 209     145000
# 210      98000
# 211     186000
# 213     156000
# 214     161750
# 216     210000
# 217     107000
# 219     167240
# 220     204900
# 223      97000
# 225     112000
# 227     106000
# 230     148000
# 233     128200
# 235      89500
# 236     185500
# 237     194500
# 238     318000
# 240     262500
# 241     110500
# 242      79000
# 246     137000
# 248     180000
# 250      76500
# 252     173000
# 253     158000
# 254     145000
# 256     207500
# 259      97000
# 263     130000
# 264      73000
# 274     124500
# 275     205000
# 276     201000
# 277     141000
# 281     185000
# 284     179200
# 285     164700
# 287      88000
# 288     122000
# 289     153575
# 291     135900
# 295     142500
# 296     152000
# 303     149900
# 305     305900
# 307      89500
# 308      82500
# 320     342643
# 323     126175
# 325      87000
# 327     145250
# 328     214500
# 329      78000
# 330     119000
# 331     139000
# 337     214000
# 338     202500
# 339     155000
# 340     202900
# 341      82000
# 342      87500
# 344      85000
# 346     151500
# 348     154000
# 352      95000
# 353     105900
# 355     177500
# 356     173000
# 358     130000
# 361     145000
# 363     118000
# 365     147000
# 372     125000
# 373     123000
# 375      61000
# 376     148000
# 382     213500
# 383      76000
# 386      81000
# 388     191000
# 390     119000
# 392     106500
# 394     109000
# 395     129000
# 396     123000
# 398      67000
# 399     241000
# 402     108000
# 406     115000
# 1439    197000
# 1440    191000
# 1441    149300
# 1442    310000
# 1443    121000
# 1447    240000
# 1451    287090
# 1455    175000
# Name: SalePrice, Length: 650, dtype: int64
# 2
#  7       200000
# 8       129900
# 9       118000
# 11      345000
# 28      207500
# 41      170000
# 70      244000
# 100     205000
# 104     169500
# 113     217000
# 118     320000
# 120     180000
# 130     226000
# 138     230000
# 161     412500
# 171     215000
# 185     475000
# 188     153337
# 190     315000
# 201     171500
# 218     311500
# 234     216500
# 244     205000
# 249     277000
# 271     241500
# 294     167000
# 300     157000
# 313     375000
# 319     187500
# 326     324000
# 334     192000
# 335     228950
# 347     157500
# 349     437154
# 354     140000
# 366     159000
# 384     240000
# 393     100000
# 400     245500
# 425     135000
# 440     555000
# 451     280000
# 457     256000
# 467     146500
# 491     133000
# 503     289000
# 510     164900
# 519     234000
# 521     150000
# 522     159000
# 529     200624
# 569     135960
# 577     164500
# 580     181900
# 585     369900
# 588     143000
# 608     359100
# 610     313000
# 619     305000
# 627     153000
# 628     135000
# 647     155000
# 662     110000
# 673     257500
# 691     755000
# 692     335000
# 706     302000
# 735     163000
# 745     299800
# 778     144000
# 791     146800
# 798     485000
# 799     175000
# 817     271000
# 830     166000
# 845     171000
# 852     164000
# 898     611657
# 939     244400
# 966     160000
# 1012    165000
# 1026    167500
# 1031    197000
# 1075    219500
# 1083    160000
# 1105    325000
# 1130    135000
# 1138    196000
# 1151    149900
# 1154    201800
# 1168    235000
# 1182    745000
# 1184    186700
# 1242    170000
# 1244    230000
# 1250    244000
# 1253    294000
# 1262    161500
# 1268    381000
# 1286    143000
# 1301    177500
# 1305    325000
# 1310    335000
# 1315    206900
# 1320    156500
# 1328    256000
# 1373    466500
# 1381    237500
# 1386    250000
# 1388    377500
# 1396    160000
# 1426    271000
# 1428    119000
# 1456    210000
# 1457    266500
# Name: SalePrice, dtype: int64
# 3
#  166     190000
# 309     360000
# 605     205000
# 642     345000
# 1298    160000
# Name: SalePrice, dtype: int64

# %% [markdown]
# #### Group continious variables to distinct classes with *cut*

# %%
train['YearBuilt_Distinct'] = pd.cut(train['YearBuilt'], [-1, 1950, 1980, 2000, 2010], labels=['Before 1951','1951-1980', '1981-1999', '2001-2010'])
train['YearBuilt_Distinct'].head()
# Out:
# 0      2001-2010
# 1      1951-1980
# 2      2001-2010
# 3    Before 1951
# 4      1981-1999
# Name: YearBuilt_Distinct, dtype: category
# Categories (4, object): [Before 1951 < 1951-1980 < 1981-1999 < 2001-2010]

# %% [markdown]
# #### Grouby and shift. First group and then keep the previous value of that grouped item.

# %%
df = pd.DataFrame({'item': ['A', 'A', 'A', 'B', 'B'],
                   'value': [11, 27, 22, 35, 52]})
df['shift'] = df.groupby(['item'])['value'].transform(lambda x: x.shift(1))
df['shift_mean'] = df.groupby(['item'])['value'].transform(lambda x: x.shift(1).mean()) #Every cell gets equal to the mean of the shift for that item. There are not NaNs
df
# Out:
#   item  value  shift  shift_mean
# 0    A     11    NaN          19
# 1    A     27   11.0          19
# 2    A     22   27.0          19
# 3    B     35    NaN          35
# 4    B     52   35.0          35

# %% [markdown]
# ### 7. Manipulating Data

# %% [markdown]
# #### Transform
# Applies to groupby. The output is the same shape as the input dataframe. The grouped values are placed in each corresponding row.

# %%
train['meanLivAreaPerYearBuilt'] = train.groupby('YearBuilt')['GrLivArea'].transform('mean')
train[['YearBuilt','meanLivAreaPerYearBuilt']][25:30] # See that same years have the same value
# Out:
#     YearBuilt  meanLivAreaPerYearBuilt
# 25       2007              1721.448980
# 26       1951              1239.166667
# 27       2007              1721.448980
# 28       1957              1379.850000
# 29       1927               838.666667

# %% [markdown]
# #### Map
# Works with Series (one column). Use it with a *lambda* function and think of it like a for loop. For each row in column 'GrLivArea', run a function

# %%
train['GrLivArea'].map(lambda x: x/train['GrLivArea'].max()).head()
# Out:
# 0    0.303084
# 1    0.223680
# 2    0.316554
# 3    0.304325
# 4    0.389578
# Name: GrLivArea, dtype: float64

# %% [markdown]
# #### Apply
# Works with DataFrame (one or more columns). Use it with *lambda* like map

# %%
train[['YearBuilt','GrLivArea']].apply(lambda x: x - x.min()).head()
# Out:
#    YearBuilt  GrLivArea
# 0        131       1376
# 1        104        928
# 2        129       1452
# 3         43       1383
# 4        128       1864

# %% [markdown]
# Or use it to get single values as answer to a function

# %%
train[['YearBuilt','GrLivArea']].apply(lambda x: x.max() - x.min())
# Out:
# YearBuilt     138
# GrLivArea    5308
# dtype: int64

# %% [markdown]
# Apply with groupby and function.

# %%
def sample_function(df):
    '''
    Takes a DataFrame grouped by a column and create a new column in the DataFrame.
    The process repeats for each group.
    '''
    a = df['GrLivArea'].mean()
    df['newColumn'] = a
    return df

# %%
train = train.groupby('YearBuilt').apply(lambda x: sample_function(x))

# %%
train[['Id','SalePrice','YearBuilt','newColumn']].head()
# Out:
#    Id  SalePrice  YearBuilt    newColumn
# 0   1     208500       2003  1681.000000
# 1   2     181500       1976  1489.909091
# 2   3     223500       2001  1739.800000
# 3   4     140000       1915  1567.900000
# 4   5     250000       2000  1737.708333

# %% [markdown]
# #### List Comprehension

# %%
train['GrLivArea_binary'] = ['big' if i>1500 else 'normal' for i in train['GrLivArea']]
train[['GrLivArea','GrLivArea_binary']].head()
# Out:
#    GrLivArea GrLivArea_binary
# 0       1710              big
# 1       1262           normal
# 2       1786              big
# 3       1717              big
# 4       2198              big

# %% [markdown]
# #### **Change/Replace** values based on condition

# %%
train.loc[train['GrLivArea'] > 1900, 'GrLivArea'] = 2001

# %%
train['GrLivArea']
# Out:
# 0       1710
# 1       1262
# 2       1786
# 3       1717
# 4       2001
# 5       1362
# 6       1694
# 7       2001
# 8       1774
# 9       1077
# 10      1040
# 11      2001
# 12       912
# 13      1494
# 14      1253
# 15       854
# 16      1004
# 17      1296
# 18      1114
# 19      1339
# 20      2001
# 21      1108
# 22      1795
# 23      1060
# 24      1060
# 25      1600
# 26       900
# 27      1704
# 28      1600
# 29       520
# 30      1317
# 31      1228
# 32      1234
# 33      1700
# 34      1561
# 35      2001
# 36      1097
# 37      1297
# 38      1057
# 39      1152
# 40      1324
# 41      1328
# 42       884
# 43       938
# 44      1150
# 45      1752
# 46      2001
# 47      1656
# 48      1452
# 49       955
# 50      1470
# 51      1176
# 52       816
# 53      1842
# 54      1360
# 55      1425
# 56      1739
# 57      1720
# 58      2001
# 59       780
# 60      1158
# 61      1111
# 62      1370
# 63      1710
# 64      2001
# 65      2001
# 66      2001
# 67      1479
# 68       747
# 69      2001
# 70      2001
# 71       845
# 72      1718
# 1449     630
# 1450    1792
# 1451    1578
# 1452    1072
# 1453    1140
# 1454    1221
# 1455    1647
# 1456    2001
# 1457    2001
# 1458    1078
# 1459    1256
# Name: GrLivArea, Length: 1460, dtype: int64

# %% [markdown]
# #### Clip. Restrict values to a lower and upper bound

# %%
train['SalePrice'].clip(0,200000)
# Out:
# 0       200000
# 1       181500
# 2       200000
# 3       140000
# 4       200000
# 5       143000
# 6       200000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      200000
# 12      144000
# 13      200000
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      200000
# 21      139400
# 22      200000
# 23      129900
# 24      154000
# 25      200000
# 26      134800
# 27      200000
# 28      200000
# 29       68500
# 30       40000
# 31      149350
# 32      179900
# 33      165500
# 34      200000
# 35      200000
# 36      145000
# 37      153000
# 38      109000
# 39       82000
# 40      160000
# 41      170000
# 42      144000
# 43      130250
# 44      141000
# 45      200000
# 46      200000
# 47      200000
# 48      113000
# 49      127000
# 50      177000
# 51      114500
# 52      110000
# 53      200000
# 54      130000
# 55      180500
# 56      172500
# 57      196500
# 58      200000
# 59      124900
# 60      158000
# 61      101000
# 62      200000
# 63      140000
# 64      200000
# 65      200000
# 66      180000
# 67      200000
# 68       80000
# 69      200000
# 70      200000
# 71      129500
# 72      185000
# 73      144900
# 74      107400
# 75       91000
# 76      135750
# 77      127000
# 78      136500
# 79      110000
# 80      193500
# 81      153500
# 82      200000
# 83      126500
# 84      168500
# 85      200000
# 86      174000
# 87      164500
# 88       85000
# 89      123600
# 90      109900
# 91       98600
# 92      163500
# 93      133900
# 94      200000
# 95      185000
# 96      200000
# 97       94750
# 98       83000
# 99      128950
# 100     200000
# 101     178000
# 102     118964
# 103     198900
# 104     169500
# 105     200000
# 106     100000
# 107     115000
# 108     115000
# 109     190000
# 110     136900
# 111     180000
# 112     200000
# 113     200000
# 114     200000
# 115     176000
# 116     139000
# 117     155000
# 118     200000
# 119     163990
# 120     180000
# 121     100000
# 122     136000
# 123     153900
# 124     181000
# 125      84500
# 126     128000
# 127      87000
# 128     155000
# 129     150000
# 130     200000
# 131     200000
# 132     150750
# 133     200000
# 134     180000
# 135     174000
# 136     143000
# 137     171000
# 138     200000
# 139     200000
# 140     115000
# 141     200000
# 142     166000
# 143     200000
# 144     125000
# 145     130000
# 146     105000
# 147     200000
# 148     141000
# 149     115000
# 150     122000
# 151     200000
# 152     190000
# 153     200000
# 154     125000
# 155      79000
# 156     109500
# 157     200000
# 158     200000
# 159     200000
# 160     162500
# 161     200000
# 162     200000
# 163     103200
# 164     152000
# 165     127500
# 166     190000
# 167     200000
# 168     183500
# 169     200000
# 170     128500
# 171     200000
# 172     200000
# 173     163000
# 174     184000
# 175     200000
# 176     200000
# 177     172500
# 178     200000
# 179     100000
# 180     177000
# 181     200000
# 182     120000
# 183     200000
# 184     127000
# 185     200000
# 186     173000
# 187     135000
# 188     153337
# 189     200000
# 190     200000
# 191     184000
# 192     192000
# 193     130000
# 194     127000
# 195     148500
# 196     200000
# 197     200000
# 198     104000
# 199     200000
# 200     140000
# 201     171500
# 202     112000
# 203     149000
# 204     110000
# 205     180500
# 1363    156932
# 1364    144152
# 1365    200000
# 1366    193000
# 1367    127000
# 1368    144000
# 1369    200000
# 1370    105000
# 1371    165500
# 1372    200000
# 1373    200000
# 1374    200000
# 1375    200000
# 1376     91000
# 1377    117000
# 1378     83000
# 1379    167500
# 1380     58500
# 1381    200000
# 1382    157000
# 1383    112000
# 1384    105000
# 1385    125500
# 1386    200000
# 1387    136000
# 1388    200000
# 1389    131000
# 1390    200000
# 1391    124000
# 1392    123000
# 1393    163000
# 1394    200000
# 1395    200000
# 1396    160000
# 1397    137500
# 1398    138000
# 1399    137450
# 1400    120000
# 1401    193000
# 1402    193879
# 1403    200000
# 1404    105000
# 1405    200000
# 1406    133000
# 1407    112000
# 1408    125500
# 1409    200000
# 1410    200000
# 1411    140000
# 1412     90000
# 1413    200000
# 1414    200000
# 1415    175900
# 1416    122500
# 1417    200000
# 1418    124000
# 1419    200000
# 1420    179900
# 1421    127500
# 1422    136500
# 1423    200000
# 1424    144000
# 1425    142000
# 1426    200000
# 1427    140000
# 1428    119000
# 1429    182900
# 1430    192140
# 1431    143750
# 1432     64500
# 1433    186500
# 1434    160000
# 1435    174000
# 1436    120500
# 1437    200000
# 1438    149700
# 1439    197000
# 1440    191000
# 1441    149300
# 1442    200000
# 1443    121000
# 1444    179600
# 1445    129000
# 1446    157900
# 1447    200000
# 1448    112000
# 1449     92000
# 1450    136000
# 1451    200000
# 1452    145000
# 1453     84500
# 1454    185000
# 1455    175000
# 1456    200000
# 1457    200000
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# #### Melt. Keep some columns and repeat the other. Grow dataframe rowise.

# %%
countries
# Out:
#         Name  Population     Area  Money
# 0     Greece       10.77  128.900  22.08
# 1   Paraguay        6.62  397.300   3.81
# 2    Ireland        4.78   68.890  45.83
# 4  Singapore        4.46    0.687  51.70
# 5      Gabon        1.64  257.670  11.43

# %%
df = pd.melt(countries, id_vars=['Name','Population'], var_name='Parameter', value_name='Value')
df
# Out:
#         Name  Population Parameter    Value
# 0     Greece       10.77      Area  128.900
# 1   Paraguay        6.62      Area  397.300
# 2    Ireland        4.78      Area   68.890
# 3  Singapore        4.46      Area    0.687
# 4      Gabon        1.64      Area  257.670
# 5     Greece       10.77     Money   22.080
# 6   Paraguay        6.62     Money    3.810
# 7    Ireland        4.78     Money   45.830
# 8  Singapore        4.46     Money   51.700
# 9      Gabon        1.64     Money   11.430

# %%
pd.pivot(df, index = 'Population', columns = 'Parameter', values = ['Value'])
# Out:
#               Value
# Parameter      Area  Money
# Population
# 1.64        257.670  11.43
# 4.46          0.687  51.70
# 4.78         68.890  45.83
# 6.62        397.300   3.81
# 10.77       128.900  22.08

# %% [markdown]
# #### Concat. Add the rows of a dataframe to another.

# %%
countries
# Out:
#         Name  Population     Area  Money
# 0     Greece       10.77  128.900  22.08
# 1   Paraguay        6.62  397.300   3.81
# 2    Ireland        4.78   68.890  45.83
# 4  Singapore        4.46    0.687  51.70
# 5      Gabon        1.64  257.670  11.43

# %%
countries2 = pd.DataFrame({
    'Name':['France', 'Finland'],
    'Population':[56.17, 5.82],
    'Area':[748.5, 205.8]
})
pd.concat([countries,countries2],sort=False)
# Out:
#         Name  Population     Area  Money
# 0     Greece       10.77  128.900  22.08
# 1   Paraguay        6.62  397.300   3.81
# 2    Ireland        4.78   68.890  45.83
# 4  Singapore        4.46    0.687  51.70
# 5      Gabon        1.64  257.670  11.43
# 0     France       56.17  748.500    NaN
# 1    Finland        5.82  205.800    NaN
